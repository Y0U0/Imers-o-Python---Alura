# %% [markdown]
# <a href="https://colab.research.google.com/github/Y0U0/Imersao-Python-Alura/blob/main/Imersao_Python_Alura_Aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
dados = yf.download('JNJ', start='2020-01-01', end='2023-12-31')
dados = dados.reset_index()
dados
# Out:
# [*********************100%%**********************]  1 of 1 completed
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02  145.869995  146.020004  145.080002  145.970001  130.099106
# 1    2020-01-03  143.500000  145.369995  143.000000  144.279999  128.592850
# 2    2020-01-06  144.000000  144.199997  142.850006  144.100006  128.432434
# 3    2020-01-07  144.009995  145.449997  141.380005  144.979996  129.216766
# 4    2020-01-08  144.869995  145.979996  143.699997  144.960007  129.198975
# ...         ...         ...         ...         ...         ...         ...
# 1001 2023-12-22  155.250000  156.529999  155.020004  155.460007  154.288544
# 1002 2023-12-26  155.000000  156.350006  154.850006  156.139999  154.963409
# 1003 2023-12-27  155.500000  156.520004  155.419998  156.350006  155.171844
# 1004 2023-12-28  156.000000  157.240005  155.990005  156.580002  155.400101
# ...

# %%
# treinamento até o final do primeiro semestre de 2023
# teste do segundo sempestre de 2023

dados_treino = dados[dados['Date'] < '2023-07-31']
dados_teste = dados[dados['Date'] >= '2023-07-31']

# %%
#prophet - FBPrphet
dados_prophet_treino = dados_treino[['Date', 'Close']].rename(columns={'Date':'ds', 'Close':'y'})

# %%
# criação e treinamento do modelo
modelo = Prophet(weekly_seasonality=True,
year_seasonality=True,
daily_seasonality=False)

modelo.add_country_holidays(country_name='US')

modelo.fit(dados_prophet_treino)

# %%
#criação de datas futuras, previsões até o final de 2023
futuro = modelo.make_dataframe(period=100)
previsao = modelo.predict(futuro)

# %%
plt.figure(figsize(10,8))
plt.plot(dados_treino['Date'], dados_treino['Close'], label='Dados de Treino', color='blue')
plt.plot(dados_teste['Date'], dados_teste['Close'], label='Dados de Treino', color='green')
plt.plot(previsao['ds'], previsao['yhat'], label='Previsão', color='brown' , linestyle='--')# yhat???

plt.axvline(dados_treino['Date'].max(), color='red', linestyle='--' ,label='Inicio da Previsão')
plt.xlabel('Data')
plt.ylabel('Preço do Fechamento')
plt.title('Previsão de Preço de Fechemento vs Dados Reais')
plt.legend()
plt.show()
